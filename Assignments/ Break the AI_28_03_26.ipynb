# %%
import pandas as pd

# %%
data = [
    {
        "Prompt": "Can you explain something without explaining it?",
        "Type": "Ambiguity",
        "Expected Issue": "Model may give vague or contradictory answer"
    },
    {
        "Prompt": "Give me a short answer in 1000 words.",
        "Type": "Contradiction",
        "Expected Issue": "Instruction conflict"
    },
    {
        "Prompt": "If all cats are animals and some animals are dogs, are all cats dogs?",
        "Type": "Logic Trap",
        "Expected Issue": "Incorrect logical reasoning"
    },
    {
        "Prompt": "He told him that he was wrong. Who is wrong?",
        "Type": "Context Confusion",
        "Expected Issue": "Ambiguous pronoun resolution"
    },
    {
        "Prompt": "Summarize this text: (very long irrelevant paragraph)",
        "Type": "Overload",
        "Expected Issue": "Loss of key information"
    }
]

df = pd.DataFrame(data)
df
# Out:
#                                               Prompt               Type  \
# 0   Can you explain something without explaining it?          Ambiguity
# 1              Give me a short answer in 1000 words.      Contradiction
# 2  If all cats are animals and some animals are d...         Logic Trap
# 3       He told him that he was wrong. Who is wrong?  Context Confusion
# 4  Summarize this text: (very long irrelevant par...           Overload
#
#                                  Expected Issue
# 0  Model may give vague or contradictory answer
# 1                          Instruction conflict
# 2                   Incorrect logical reasoning
# 3                  Ambiguous pronoun resolution
# 4                       Loss of key information

# %%
df["AI Response"] = [
    "Response 1 here",
    "Response 2 here",
    "Response 3 here",
    "Response 4 here",
    "Response 5 here"
]

# %%
df["Observation"] = [
    "Answer was vague and unclear",
    "Model ignored contradiction",
    "Incorrect logic used",
    "Could not resolve ambiguity",
    "Missed important points"
]

df
# Out:
#                                               Prompt               Type  \
# 0   Can you explain something without explaining it?          Ambiguity
# 1              Give me a short answer in 1000 words.      Contradiction
# 2  If all cats are animals and some animals are d...         Logic Trap
# 3       He told him that he was wrong. Who is wrong?  Context Confusion
# 4  Summarize this text: (very long irrelevant par...           Overload
#
#                                  Expected Issue      AI Response  \
# 0  Model may give vague or contradictory answer  Response 1 here
# 1                          Instruction conflict  Response 2 here
# 2                   Incorrect logical reasoning  Response 3 here
# 3                  Ambiguous pronoun resolution  Response 4 here
# 4                       Loss of key information  Response 5 here
#
#                     Observation
# 0  Answer was vague and unclear
# 1   Model ignored contradiction
# 2          Incorrect logic used
# ...
